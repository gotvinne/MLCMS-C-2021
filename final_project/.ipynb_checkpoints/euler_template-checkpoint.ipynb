# %% [markdown]
# # Task 2: Implementing a neural network utilizing Euler's method

# %%
from sw.IntegratorNN import *
from sw.dataformating import get_train_and_val_data, get_sim_data
from sw.simulation import *
from sw.plotting import *

from torch.utils.data import DataLoader

# %% [markdown]
# ## Hyperparameters:

# %%
LR = 1e-5 #learning rate
BATCHES = 256
EPOCHS = 5

INPUT_SIZE = 2
OUTPUT_SIZE = 2
DEPTH = 100

# %% [markdown]
# ## Formating data for input:

# %%
train_percent = 80
train_data, val_data = get_train_and_val_data("datasets/postvis.csv",train_percent)

trainset = DataLoader(train_data,batch_size=BATCHES,shuffle=True)
valset = DataLoader(val_data,shuffle=True)

# %% [markdown]
# ## Training NN with Euler template:

# %%
integratorNN = IntegratorNN(INPUT_SIZE,DEPTH,OUTPUT_SIZE)
integratorNN.training(LR,EPOCHS,trainset)

"""
loss_data = training(integratorNN,LR,EPOCHS,trainset)
val_loss, train_step = validating(integratorNN,LR,trainset,valset)
print(val_loss)
print(train_step)
"""
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ww/g5mppd_d60x1md9x4xsbpcpr0000gn/T/ipykernel_39692/1742305348.py in <module>
#       1 integratorNN = IntegratorNN(INPUT_SIZE,DEPTH,OUTPUT_SIZE)
# ----> 2 integratorNN.training(LR,EPOCHS,trainset)
#       3
#       4 """
#       5 loss_data = training(integratorNN,LR,EPOCHS,trainset)
#
# TypeError: 'bool' object is not callable

# %% [markdown]
# ## Testing model:
# Here we use the validation set as input and solve for the position using scipy.solve_ivp()

# %%
#Solving trajectory.
t = 35
num = 10

traj = simulate_trajectories(num,t,integratorNN,"datasets/postvis.csv")
plot_trajectories(num,traj)

# %% [markdown]
# ## Phase plot:

# %%
phase_plot(integratorNN)
