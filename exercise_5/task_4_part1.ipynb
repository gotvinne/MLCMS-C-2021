# %% [markdown]
# # Reconstruct periodic signal

# %%
#imports
import numpy as np
import sw.task4_part1 as t4

# %%
# Data set filepaths:
takens_filepath = "datasets/takens_1.txt"

# %%
# Load data from takens_1 dataset
data = np.loadtxt(takens_filepath)
x = data[:,0]
y = data[:,1]

# %% [markdown]
# ## Plot periodic signal

# %%
t4.plot_coordinate_values_over_time(x)

# %% [markdown]
# # Reconstruct Shadow manifold

# %%
t4. plot_reconstruction_of_shadow_manifold(x)
