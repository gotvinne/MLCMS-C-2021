# %% [markdown]
# # Task 4: Chaotic dynamics

# %% [markdown]
# ## Part 1: Consider the discrete map:
# ![x_{n+1} = r x_{n}(1-x_{n}), n \in \mathbb{R}](https://latex.codecogs.com/gif.latex?x_{n&plus;1}&space;=&space;r&space;x_{n}(1-x_{n}),&space;n&space;\in&space;\mathbb{N})
#
# x = 1 and x = 0 are trivial steady states, where x = 0 is unstable and x = 1 stable

# %%
# Imports
import sw.task4 as t4

# %% [markdown]
# ## Examining the system for r = [0,2]
# We can examine the bifurcation by plotting the flow for some bifurcation values

# %%
x0 = 0.1
tend = 100

# %%
t4.logistic_bifurcations(0,2,x0,tend)

# %% [markdown]
# ## Examining the system for r = [2,4]

# %%
t4.logistic_bifurcations(2,4,x0,tend)

# %% [markdown]
# ## Bifurcation diagram of discrete map

# %%
tend = 100
r_step = 0.001
t4.logistic_bifurcation_diagram(0,4,x0,tend,r_step)
