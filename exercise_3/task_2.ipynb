# %% [markdown]
# # Task 2: Common bifurcations in nonlinear systems

# %% [markdown]
# ## Systems:
# <img src="https://latex.codecogs.com/svg.latex?\dot&space;x&space;=&space;\alpha&space;-&space;x^2,&space;\alpha&space;=&space;\mathbb{R}" title="\dot x = \alpha - x^2, \alpha = \mathbb{R}" />
# <img src="https://latex.codecogs.com/svg.latex?\dot&space;x&space;=&space;\alpha&space;-&space;2x^2&space;-3" title="\dot x = \alpha - 2x^2 -3" />

# %%
#import
import numpy as np
import sw.task2 as t2

# %% [markdown]
# ### Bifurcation diagram for first system (a=1, b=0)

# %%
# Create alpha values as input
alpha = np.linspace(-1, 1, num =100)

# %%
start_alpha, pos_equli, neg_equli = t2.nonlinear_equilibria(alpha, 1, 0)
t2.bifurcation_plot(alpha,start_alpha, pos_equli, neg_equli)

# %% [markdown]
# ### Bifurcation diagram for second system (a=2, b=3)

# %%
#Create alpha values as input
alpha = np.linspace(1,5,num=100)

# %%
start_alpha, pos_equli, neg_equli = t2.nonlinear_equilibria(alpha, 2, 3)
t2.bifurcation_plot(alpha,start_alpha, pos_equli, neg_equli)
